# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#64-QAM plot with P-equivalent dB
#Import required values generated by other scripts
rho = 0.885838
ser = [0.151615625, 0.0982875, 0.057665625, 0.02974375, 0.01350625, 0.0053125, 0.001853125, 0.000490625]
designedModSER = [0.1244125, 0.0757984375, 0.0415984375, 0.0196890625, 0.007725, 0.0026171875, 0.000746875, 0.0001703125]
CDrectSER = [0.204797, 0.141373, 0.09003, 0.051446, 0.025708, 0.010862, 0.003649, 0.000997]
SplitRho1 = [0.220246875, 0.15469166666666667, 0.10069166666666667, 0.059336458333333335, 0.030385416666666668, 0.013601041666666668, 0.005085416666666667, 0.0014916666666666667]
P_dB = np.arange(20,28,1) #P value in dB
plt.figure(num=None,figsize=(8,5),dpi=80)
plt.plot(P_dB,CDrectSER,'kv:',P_dB,ser,'ro-',P_dB,designedModSER,'bx--',P_dB,SplitRho1,'g^-.')
plt.yscale('log')
plt.grid(which='minor',linestyle=':')
plt.grid('major',linestyle='-')
plt.title('SER vs equivalent transmission power in dB')
plt.xlabel('P (dB)')
plt.ylabel('SER')
QAMlabel='Rectangular 64-QAM (rho='+"{:.3f}".format(rho)+')'
plt.legend(['Traditional Rectangular 64-QAM',QAMlabel,'Designed Modulation Scheme','Network with Fixed Rho (rho=1)'])

# %%
#Copy of the above plot but with EbNo as units instead of P
#Import required values generated by other scripts
rho = 0.885838
ser = [0.151615625, 0.0982875, 0.057665625, 0.02974375, 0.01350625, 0.0053125, 0.001853125, 0.000490625]
designedModSER = [0.1244125, 0.0757984375, 0.0415984375, 0.0196890625, 0.007725, 0.0026171875, 0.000746875, 0.0001703125]
CDrectSER = [0.204797, 0.141373, 0.09003, 0.051446, 0.025708, 0.010862, 0.003649, 0.000997]
SplitRho1 = [0.220246875, 0.15469166666666667, 0.10069166666666667, 0.059336458333333335, 0.030385416666666668, 0.013601041666666668, 0.005085416666666667, 0.0014916666666666667]
EbNodB = np.arange(12.2,20,1) #P value in dB
plt.figure(num=None,figsize=(8,5),dpi=80)
plt.plot(EbNodB,CDrectSER,'kv:',EbNodB,ser,'ro-',EbNodB,designedModSER,'bx--',EbNodB,SplitRho1,'g^-.')
plt.yscale('log')
plt.grid(which='minor',linestyle=':')
plt.grid('major',linestyle='-')
plt.title('SER vs EbNo for 64-QAM')
plt.xlabel('EbNo (dB)')
plt.ylabel('SER')
QAMlabel='Rectangular 64-QAM (rho='+"{:.3f}".format(rho)+')'
plt.legend(['Traditional Rectangular 64-QAM',QAMlabel,'Designed Modulation Scheme','Network with Fixed Rho (rho=1)'])

# %%
#64-QAM for 10dB increased CD EbNo (SNR)
rect_rho = 0.72833204
SplitRectSER = [0.075005, 0.0408946875, 0.019546875, 0.008013125, 0.0027059375, 0.00070625, 0.000134375, 2.15625e-05]
designedModSER = [0.0613515625, 0.031653125, 0.0144625, 0.0054625, 0.001659375, 0.0003890625, 7.8125e-05, 9.375e-06]
CDrectSER = [0.072533, 0.039718, 0.018602, 0.007185, 0.002284, 0.000564, 0.000106, 8e-06]
SplitRho1 = [0.0756203125, 0.041540625, 0.01975625, 0.008096875, 0.0026921875, 0.0006890625, 0.0001453125, 2.34375e-05]
EbNodB = np.arange(12,20,1) #P value in dB
plt.figure(num=None,figsize=(8,5),dpi=80)
plt.plot(EbNodB,CDrectSER,'kv:',EbNodB,SplitRectSER,'ro-',EbNodB,designedModSER,'bx--',EbNodB,SplitRho1,'g^-.')
plt.yscale('log')
plt.grid(which='minor',linestyle=':')
plt.grid('major',linestyle='-')
plt.title('SER vs EbNo for Increased CD Pathway EbNo')
plt.xlabel('EbNo (dB)')
plt.ylabel('SER')
QAMlabel='Rectangular 64-QAM (rho='+"{:.3f}".format(rect_rho)+')'
plt.legend(['Traditional Rectangular 64-QAM',QAMlabel,'Designed Modulation Scheme','Rectangular 64-QAM Trained with Fixed Rho (rho=1)'])

# %%
#64-QAM for 10dB increased PD EbNo (SNR)
rect_rho = 0.85769147
SplitRectSER = [0.161196875, 0.1070375, 0.0645, 0.035159375, 0.01728125, 0.007240625, 0.002603125, 0.00076875]
designedModSER = [0.124540625, 0.07663125, 0.04144375, 0.0198125, 0.007865625, 0.0026125, 0.00060625, 0.000140625]
CDrectSER = [0.204797, 0.141373, 0.09003, 0.051446, 0.025708, 0.010862, 0.003649, 0.000997]
SplitRho1 = [0.2204046875, 0.1563453125, 0.1017171875, 0.059703125, 0.03133125, 0.01389375, 0.005196875, 0.0016390625]
EbNodB = np.arange(12,20,1) #P value in dB
plt.figure(num=None,figsize=(8,5),dpi=80)
plt.plot(EbNodB,CDrectSER,'kv:',EbNodB,SplitRectSER,'ro-',EbNodB,designedModSER,'bx--',EbNodB,SplitRho1,'g^-.')
plt.yscale('log')
plt.grid(which='minor',linestyle=':')
plt.grid('major',linestyle='-')
plt.title('SER vs EbNo for Increased PD Pathway EbNo')
plt.xlabel('EbNo (dB)')
plt.ylabel('SER')
QAMlabel='Rectangular 64-QAM (rho='+"{:.3f}".format(rect_rho)+')'
plt.legend(['Traditional Rectangular 64-QAM',QAMlabel,'Designed Modulation Scheme','Rectangular 64-QAM Trained with Fixed Rho (rho=1)'])

# %%
#64-QAM for 10dB increased Channel EbNo (SNR)
rect_rho = 0.8961102
SplitRectSER = [0.028344791666666667, 0.013672916666666667, 0.005636458333333334, 0.0021822916666666666, 0.0007208333333333333, 0.000215625, 3.75e-05, 3.125e-06]
designedModSER = [0.01829375, 0.008321875, 0.0031947916666666665, 0.001065625, 0.0003083333333333333, 4.791666666666667e-05, 1.0416666666666666e-05, 2.0833333333333334e-06]
CDrectSER = [0.072798, 0.039534, 0.018329, 0.007257, 0.002266, 0.000552, 7.7e-05, 1.1e-05]
SplitRho1 = [0.07670625, 0.0420875, 0.020103125, 0.008384375, 0.0028625, 0.0007375, 0.000146875, 2.5e-05]
EbNodB = np.arange(12,20,1) #P value in dB
plt.figure(num=None,figsize=(8,5),dpi=80)
plt.plot(EbNodB,CDrectSER,'kv:',EbNodB,SplitRectSER,'ro-',EbNodB,designedModSER,'bx--',EbNodB,SplitRho1,'g^-.')
plt.yscale('log')
plt.grid(which='minor',linestyle=':')
plt.grid('major',linestyle='-')
plt.title('SER vs EbNo for Increased Channel EbNo')
plt.xlabel('EbNo (dB)')
plt.ylabel('SER')
QAMlabel='Rectangular 64-QAM (rho='+"{:.3f}".format(rect_rho)+')'
plt.legend(['Traditional Rectangular 64-QAM',QAMlabel,'Designed Modulation Scheme','Rectangular 64-QAM Trained with Fixed Rho (rho=1)'])

# %%
# 16-QAM O'Shea Paper error rates
RectSER = [0.4792039, 0.3522435, 0.2205529, 0.1084602, 0.0366116, 0.007034, 0.0005515, 1.26e-05]
UnoptSER1 = [0.4707625, 0.33990625, 0.20916875, 0.09801875, 0.03141875, 0.00554375, 0.00038125, 1.25e-05]
UnoptSER2 = [0.4633625, 0.3310875, 0.20286875, 0.0926, 0.029825, 0.00504375, 0.0004125, 1.875e-05]
OptSER = [0.46210625, 0.33144375, 0.1989125, 0.0911625, 0.02870625, 0.00481875, 0.0003875, 1.25e-05]
EbNodB = np.arange(0,15,2)
plt.figure(num=None,figsize=(8,5),dpi=80)
plt.plot(EbNodB,RectSER,'kv:',EbNodB,UnoptSER1,'ro-',EbNodB,UnoptSER2,'g^-.',EbNodB,OptSER,'bx--')
plt.yscale('log')
plt.grid(which='minor',linestyle=':')
plt.grid('major',linestyle='-')
plt.title('SER vs EbNo for 16-QAM')
plt.xlabel('EbNo (dB)')
plt.ylabel('SER')
plt.legend(['Traditional Rectangular 16-QAM','Trained Scheme 1','Trained Scheme 2','Target Scheme'])

# %%
#Unused, takes too long to generate useful data at relevant EbNo
## 16-QAM O'Shea Paper error rates v2, some trained at 10dB 
#RectSER = [0.4792039, 0.3522435, 0.2205529, 0.1084602, 0.0366116, 0.007034, 0.0005515, 1.26e-05]
#UnoptSER1 = [0.474014375, 0.34393125, 0.211861875, 0.099153125, 0.030845, 0.005185625, 0.000345625, 6.25e-06]
#UnoprtSER2 = [0.4643175, 0.336410625, 0.204894375, 0.09617375, 0.030015, 0.005006875, 0.0003125, 6.875e-06]
#OptSER7 = [0.46210625, 0.33144375, 0.1989125, 0.0911625, 0.02870625, 0.00481875, 0.0003875, 1.25e-05]
#EbNodB = np.arange(0,15,2)
#plt.figure(num=None,figsize=(8,5),dpi=80)
#plt.plot(EbNodB,RectSER,'kv:',EbNodB,UnoptSER1,'ro-',EbNodB,UnoptSER2,'g^-.',EbNodB,OptSER7,'bx--')
#plt.yscale('log')
#plt.grid(which='minor',linestyle=':')
#plt.grid('major',linestyle='-')
#plt.title('SER vs EbNo for 16-QAM')
#plt.xlabel('EbNo (dB)')
#plt.ylabel('SER')
#plt.legend(['Rectangular 16-QAM','Trained Scheme 1','Trained Scheme 2','Target Scheme'])

# %%
#Splitting receiver for 16-QAM - best results
#TODO - split this into three plots. One with 10dB+CD, one with both designeds and one with both rects.
#       This should best display the varied importance of training Noise values. Given the small amount of time needed for training, recommend just trying a few values
rect_rho10 = 0.8489135
rect_split_ser10 = [0.6522125, 0.57436875, 0.48011875, 0.37381875, 0.26331875, 0.1639625, 0.0871125, 0.0366125, 0.0122625, 0.00280625, 0.00035625]
designedModSER10 = [0.63564375, 0.55303125, 0.45715, 0.3494375, 0.23925625, 0.14006875, 0.0668125, 0.02370625, 0.00569375, 0.0007875, 8.125e-05]
CDrectSER = [0.633939, 0.563375, 0.47853, 0.385671, 0.286414, 0.190302, 0.108672, 0.050549, 0.017744, 0.004188, 0.000594]
EbNo = np.arange(0,16,1.5)
plt.figure(num=None,figsize=(8,5),dpi=80)
plt.plot(EbNo,CDrectSER,'kv:',EbNo,rect_split_ser10,'r^-',EbNo,designedModSER10,'bx-')
plt.yscale('log')
plt.grid(which='minor',linestyle=':')
plt.grid('major',linestyle='-')
plt.title('SER vs EbNo for 16-QAM Splitting Receivers')
plt.xlabel('EbNo (dB)')
plt.ylabel('SER')
QAMlabel10='Rectangular 16-QAM (rho='+"{:.3f}".format(rect_rho10)+')'
plt.legend(['Traditional Rectangular 16-QAM',QAMlabel10,'Designed Modulation Scheme'])

# %%
#16 QAM splitting training ebno comparison designed mod
designedModSER4 = [0.6030625, 0.5227375, 0.43275, 0.3413625, 0.2601125, 0.1961875, 0.1545, 0.13311875, 0.1230125, 0.11836875, 0.1168]
designedModSER7 = [0.62164375, 0.53623125, 0.43575, 0.33138125, 0.22834375, 0.141125, 0.07610625, 0.03728125, 0.019, 0.01025, 0.00531875]
designedModSER10 = [0.63564375, 0.55303125, 0.45715, 0.3494375, 0.23925625, 0.14006875, 0.0668125, 0.02370625, 0.00569375, 0.0007875, 8.125e-05]
designedModSER13 = [0.6473375, 0.5690625, 0.47203125, 0.35923125, 0.2492125, 0.14690625, 0.0689375, 0.0260125, 0.00585, 0.00090625, 3.75e-05]
CDrectSER = [0.633939, 0.563375, 0.47853, 0.385671, 0.286414, 0.190302, 0.108672, 0.050549, 0.017744, 0.004188, 0.000594]
EbNo = np.arange(0,16,1.5)
plt.figure(num=None,figsize=(8,5),dpi=80)
plt.plot(EbNo,CDrectSER,'kv:',EbNo,designedModSER4,'r^-',EbNo,designedModSER7,'gX--',EbNo,designedModSER10,'bx-',EbNo,designedModSER13,'c>-')
plt.yscale('log')
plt.grid(which='minor',linestyle=':')
plt.grid('major',linestyle='-')
plt.title('Comparison of Designed Schemes Changing Training EbNo')
plt.xlabel('EbNo (dB)')
plt.ylabel('SER')
plt.legend(['Traditional Rectangular 16-QAM','Designed Modulation Scheme (Training EbNo=4dB)',
            'Designed Modulation Scheme (Training EbNo=7dB)','Designed Modulation Scheme (Training EbNo=10dB)',
            'Designed Modulation Scheme (Training EbNo=13dB)'])

# %%
#16 QAM splitting training ebno comparison rectangular mod
rect_rho4 = 0.7563875
rect_rho7 = 0.7943148
rect_rho10 = 0.8490246
rect_rho13 = 0.8924817
rect_split_ser4 = [0.6399125, 0.55850625, 0.4650625, 0.36488125, 0.2631, 0.1658875, 0.09094375, 0.0406125, 0.01426875, 0.0038375, 0.00069375]
rect_split_ser7 = [0.64375625, 0.5645, 0.46941875, 0.366625, 0.25999375, 0.16240625, 0.0886125, 0.03963125, 0.0133875, 0.00309375, 0.000425]
rect_split_ser10 = [0.65439375, 0.57411875, 0.48176875, 0.37425, 0.26485625, 0.165025, 0.0879125, 0.03743125, 0.0116, 0.00286875, 0.0004625]
rect_split_ser13 = [0.67810625, 0.59989375, 0.505775, 0.3952875, 0.28058125, 0.17274375, 0.0901625, 0.038225, 0.012325, 0.00229375, 0.00031875]
CDrectSER = [0.633939, 0.563375, 0.47853, 0.385671, 0.286414, 0.190302, 0.108672, 0.050549, 0.017744, 0.004188, 0.000594]
EbNo = np.arange(0,16,1.5)
plt.figure(num=None,figsize=(8,5),dpi=80)
plt.plot(EbNo,CDrectSER,'kv:',EbNo,rect_split_ser4,'r^:',EbNo,rect_split_ser7,'gX:',EbNo,rect_split_ser10,'bx:',EbNo,rect_split_ser13,'c>:')
plt.yscale('log')
plt.grid(which='minor',linestyle=':')
plt.grid('major',linestyle='-')
plt.title('SER vs EbNo for 16-QAM Splitting Receivers')
plt.xlabel('EbNo (dB)')
plt.ylabel('SER')
QAMlabel4='Rectangular 16-QAM (rho='+"{:.3f}".format(rect_rho4)+', Training Ebno=4dB)'
QAMlabel7='Rectangular 16-QAM (rho='+"{:.3f}".format(rect_rho7)+', Training Ebno=7dB)'
QAMlabel10='Rectangular 16-QAM (rho='+"{:.3f}".format(rect_rho10)+', Training Ebno=10dB)'
QAMlabel13='Rectangular 16-QAM (rho='+"{:.3f}".format(rect_rho13)+', Training Ebno=13dB)'
plt.legend(['Traditional Rectangular 16-QAM',QAMlabel4,QAMlabel7,QAMlabel10,QAMlabel13])

# %%
#Splitting receiver for 256-QAM
rect_rho = 0.8619334
rect_split_ser = [0.22022265625, 0.1540546875, 0.1008046875, 0.0594921875, 0.031765625, 0.014890625, 0.006125, 0.00223828125, 0.00069140625, 0.0001796875, 2.734375e-05]
designedModSER = [0.18584375, 0.12504296875, 0.078171875, 0.043984375, 0.021796875, 0.0090859375, 0.00328515625, 0.00093359375, 0.0002421875, 3.515625e-05, 3.90625e-06]
CDrectSER = [0.295101, 0.220493, 0.152423, 0.097263, 0.055987, 0.027561, 0.011832, 0.004028, 0.001145, 0.000208, 2.8e-05]
SplitRho1 = [0.29926953125, 0.22276171875, 0.15663671875, 0.10144140625, 0.05881640625, 0.03053515625, 0.01329296875, 0.00515625, 0.00151953125, 0.00036328125, 6.640625e-05]
EbNo = np.arange(16,27,1)
plt.figure(num=None,figsize=(8,5),dpi=80)
plt.plot(EbNo,CDrectSER,'kv:',EbNo,rect_split_ser,'r^-',EbNo,designedModSER,'bx--',EbNo,SplitRho1,'g^-.')
plt.yscale('log')
plt.grid(which='minor',linestyle=':')
plt.grid('major',linestyle='-')
plt.title('SER vs EbNo for 256-QAM Splitting Receivers')
plt.xlabel('EbNo (dB)')
plt.ylabel('SER')
QAMlabel='Rectangular 256-QAM (rho='+"{:.3f}".format(rect_rho)+')'
plt.legend(['Traditional Rectangular 256-QAM',QAMlabel,'Designed Modulation Scheme','Network with Fixed Rho (rho=1)'])
